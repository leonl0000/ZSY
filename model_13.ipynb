# %%
import model_generator as mg
model = mg.Model([300, 400, 40, 1], 'Model13',  r_discount=.95, c_discount=1)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=10, learning_rate=0.0001)
# Out:
# num minibatches:3662
# 	Epoch time:40 seconds
# Cost after epoch 0: 0.843451
# 	Dev error (no dropout): 0.760963
# Cost after epoch 1: 0.757536
# 	Dev error (no dropout): 0.747972
# Cost after epoch 2: 0.743420
# 	Dev error (no dropout): 0.739171
# Cost after epoch 3: 0.734373
# 	Dev error (no dropout): 0.732754
# Cost after epoch 4: 0.727734
# 	Dev error (no dropout): 0.729081
# Cost after epoch 5: 0.723006
# 	Dev error (no dropout): 0.727104
# Cost after epoch 6: 0.719114
# 	Dev error (no dropout): 0.724138
# Cost after epoch 7: 0.716386
# 	Dev error (no dropout): 0.721284
# Cost after epoch 8: 0.714108
# 	Dev error (no dropout): 0.722618
# Cost after epoch 9: 0.712061
# 	Dev error (no dropout): 0.719752
# Parameters have been trained!
# Train cost (No dropout): 0.7036671
# Test cost (No dropout): 0.7197523

# %%
import zsyGame as zsy
zsy.stdTest("Model13/params_Model13_1.pkl", 10000)
