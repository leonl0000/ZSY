# %%
import model_generator as mg
model = mg.Model([300, 100, 100, 40, 1], 'Model4',  r_discount=1, c_discount=.9)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=100, learning_rate=0.001)
# Out:
# num minibatches:3662
# 	Epoch time:44 seconds
# Cost after epoch 0: 2.210876
# 	Dev error (no dropout): 2.118076
# Cost after epoch 1: 2.130645
# 	Dev error (no dropout): 2.104681
# Cost after epoch 2: 2.114111
# 	Dev error (no dropout): 2.090941
# Cost after epoch 3: 2.109680
# 	Dev error (no dropout): 2.098770
# Cost after epoch 4: 2.109671
# 	Dev error (no dropout): 2.098037
# Cost after epoch 5: 2.098591
# 	Dev error (no dropout): 2.074795
# Cost after epoch 6: 2.101910
# 	Dev error (no dropout): 2.086666
# Cost after epoch 7: 2.107276
# 	Dev error (no dropout): 2.075230
# Cost after epoch 8: 2.105252
# 	Dev error (no dropout): 2.094452
# Cost after epoch 9: 2.098466
# 	Dev error (no dropout): 2.118335
# 	Ave epoch time: 32.729141
# 	100 epochs will take 0:54:32.914150
# Cost after epoch 10: 2.111047
# 	Dev error (no dropout): 2.078504
# Cost after epoch 20: 2.128492
# 	Dev error (no dropout): 2.126352
# Cost after epoch 30: 2.150372
# 	Dev error (no dropout): 2.089859
# Cost after epoch 40: 2.185625
# 	Dev error (no dropout): 2.134933
# Cost after epoch 50: 2.195620
# 	Dev error (no dropout): 2.107040
# Cost after epoch 60: 2.204499
# 	Dev error (no dropout): 2.107524
# Cost after epoch 70: 2.209539
# 	Dev error (no dropout): 2.161887
# Cost after epoch 80: 2.227600
# 	Dev error (no dropout): 2.146591
# Cost after epoch 90: 2.214758
# 	Dev error (no dropout): 2.148184
# Parameters have been trained!
# Train cost (No dropout): 2.1949866
# Test cost (No dropout): 2.2336376

# %%
model.TestModel()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-133c7b7b6eb7> in <module>()
# ----> 1 model.TestModel()
#
# ~/zsy/model_generator.py in TestModel(self)
#     148
#     149     def TestModel(self):
# --> 150         zsy.stdTest(self.paramFileName)
#     151
#     152     def GenerateTrainingData(self, numGames=100000, exploration_prob=0.1):
#
# ~/zsy/zsyGame.py in stdTest(paramFileName, numGames)
#      88     dQP = dQParameterSetInstance(paramFileName, globalSess)
#      89     dQA = DeepQAgent(predictor = dQP, exploration_prob=0)
# ---> 90     vg = np.sum([game(dQA, greedyAgent)[1] for _ in range(numGames)])
#      91     vr = np.sum([game(dQA, randomAgent)[1] for _ in range(numGames)])
#      92     print("VS Greedy: %.3f%%\tVS Random: %.3f%%"%(100.*vg/numGames, 100.*vr/numGames))
#
# ~/zsy/zsyGame.py in <listcomp>(.0)
#      88     dQP = dQParameterSetInstance(paramFileName, globalSess)
#      89     dQA = DeepQAgent(predictor = dQP, exploration_prob=0)
# ---> 90     vg = np.sum([game(dQA, greedyAgent)[1] for _ in range(numGames)])
#      91     vr = np.sum([game(dQA, randomAgent)[1] for _ in range(numGames)])
#      92     print("VS Greedy: %.3f%%\tVS Random: %.3f%%"%(100.*vg/numGames, 100.*vr/numGames))
#
# ~/zsy/zsyGame.py in game(agentA, agentB, verbose)
#      77             B -= history[-1]
#      78         else:
# ---> 79             history.append(agentA.getMove(gameStates[-1]))
#      80             A -= history[-1]
#      81         i += 1
#
# ~/zsy/agents/dQAgent.py in getMove(self, g)
#      85         moves = dc.getMovesFromGameState(g)
#      86         X = flattenSAGenerator(g, moves)
# ---> 87         scores = self.predictor.predict(X)
#      88         if np.all(scores==0):
#      89             if len(moves) == 1:
#
# ~/zsy/agents/dQAgent.py in predict(self, x)
#      63
#      64     def predict(self, x):
# ---> 65         return self.sess.run(self.params['A'+str(self.n_layers)], feed_dict = {self.params['X']: x})
#      66
#      67
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model.paramFileName
# Out:
# '/home/ubuntu/zsy/Model4/params_Model4_1.pkl'

# %%
import zsyGame as zsy

# %%
zsy.stdTest(model.paramFileName, 100)
# Out:
# VS Greedy: 11.000%	VS Random: 10.000%
# Standard metric: 8010.00
