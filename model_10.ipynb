# %%
import model_generator as mg
model = mg.Model([300, 400, 40, 1], 'Model10',  r_discount=.8, c_discount=1)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=10, learning_rate=0.001)
# Out:
# num minibatches:3662
# 	Epoch time:76 seconds
# Cost after epoch 0: 0.647556
# 	Dev error (no dropout): 0.644499
# Cost after epoch 1: 0.634615
# 	Dev error (no dropout): 0.629892
# Cost after epoch 2: 0.632491
# 	Dev error (no dropout): 0.626333
# Cost after epoch 3: 0.631531
# 	Dev error (no dropout): 0.625402
# Cost after epoch 4: 0.629766
# 	Dev error (no dropout): 0.623675
# Cost after epoch 5: 0.630814
# 	Dev error (no dropout): 0.627268
# Cost after epoch 6: 0.631126
# 	Dev error (no dropout): 0.625226
# Cost after epoch 7: 0.630584
# 	Dev error (no dropout): 0.626626
# Cost after epoch 8: 0.630811
# 	Dev error (no dropout): 0.622899
# Cost after epoch 9: 0.631472
# 	Dev error (no dropout): 0.627602
# Parameters have been trained!
# Train cost (No dropout): 0.6268049
# Test cost (No dropout): 0.6276023

# %%
import zsyGame as zsy
zsy.stdTest(model.paramFileName, 1000)
# Out:
# VS Greedy: 42.000%	VS Random: 84.800%
# Standard metric: 881.60
