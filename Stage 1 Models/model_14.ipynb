# %%
import model_generator as mg
model = mg.Model([300, 400, 40, 1], 'Model14',  r_discount=.95, c_discount=.99)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=10, learning_rate=0.0001)
# Out:
# num minibatches:3662
# 	Epoch time:37 seconds
# Cost after epoch 0: 0.774996
# 	Dev error (no dropout): 0.692652
# Cost after epoch 1: 0.690376
# 	Dev error (no dropout): 0.681751
# Cost after epoch 2: 0.677178
# 	Dev error (no dropout): 0.671129
# Cost after epoch 3: 0.668529
# 	Dev error (no dropout): 0.666063
# Cost after epoch 4: 0.662263
# 	Dev error (no dropout): 0.664004
# Cost after epoch 5: 0.657309
# 	Dev error (no dropout): 0.660904
# Cost after epoch 6: 0.654375
# 	Dev error (no dropout): 0.657786
# Cost after epoch 7: 0.651012
# 	Dev error (no dropout): 0.655472
# Cost after epoch 8: 0.649050
# 	Dev error (no dropout): 0.654688
# Cost after epoch 9: 0.646928
# 	Dev error (no dropout): 0.654415
# Parameters have been trained!
# Train cost (No dropout): 0.64045715
# Test cost (No dropout): 0.6544151

# %%
import zsyGame as zsy
zsy.stdTest(model.paramFileName, 10000)
# Out:
# VS Greedy: 63.340%	VS Random: 94.730%
# Standard metric: 193.20
