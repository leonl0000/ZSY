# %%
import model_generator as mg
model = mg.Model([300, 400, 40, 1], 'Model9',  r_discount=1, c_discount=1)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=10, learning_rate=0.001)
# Out:
# num minibatches:3662
# 	Epoch time:59 seconds
# Cost after epoch 0: 5.684807
# 	Dev error (no dropout): 5.642841
# Cost after epoch 1: 5.552285
# 	Dev error (no dropout): 5.597937
# Cost after epoch 2: 5.517382
# 	Dev error (no dropout): 5.609572
# Cost after epoch 3: 5.493298
# 	Dev error (no dropout): 5.537982
# Cost after epoch 4: 5.490409
# 	Dev error (no dropout): 5.550456
# Cost after epoch 5: 5.486180
# 	Dev error (no dropout): 5.536939
# Cost after epoch 6: 5.479721
# 	Dev error (no dropout): 5.533363
# Cost after epoch 7: 5.481116
# 	Dev error (no dropout): 5.514729
# Cost after epoch 8: 5.479580
# 	Dev error (no dropout): 5.572678
# Cost after epoch 9: 5.473993
# 	Dev error (no dropout): 5.521395
# Parameters have been trained!
# Train cost (No dropout): 5.38416
# Test cost (No dropout): 5.521395

# %%
import zsyGame as zsy
zsy.stdTest(model.paramFileName, 1000)
# Out:
# VS Greedy: 18.600%	VS Random: 23.700%
# Standard metric: 6210.82
