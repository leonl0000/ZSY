# %%
import model_generator as mg
model = mg.Model([300, 400, 40, 1], 'Model_2-2', 
                 dataFilename = 'Model_2-2/T100k_1.pkl', 
                 paramFileName = 'Model_2-2/params_Model_2-2_1.pkl', r_discount=.95, c_discount=1)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=20, learning_rate=0.0001)
# Out:
# num minibatches:617
# 	Epoch time:6 seconds
# Cost after epoch 0: 0.859389
# 	Dev error (no dropout): 0.816572
# Cost after epoch 1: 0.827258
# 	Dev error (no dropout): 0.806068
# Cost after epoch 2: 0.814417
# 	Dev error (no dropout): 0.803262
# Cost after epoch 3: 0.806697
# 	Dev error (no dropout): 0.796200
# Cost after epoch 4: 0.799297
# 	Dev error (no dropout): 0.795881
# Cost after epoch 5: 0.792635
# 	Dev error (no dropout): 0.790805
# Cost after epoch 6: 0.788836
# 	Dev error (no dropout): 0.788518
# Cost after epoch 7: 0.783363
# 	Dev error (no dropout): 0.787644
# Cost after epoch 8: 0.779165
# 	Dev error (no dropout): 0.786313
# Cost after epoch 9: 0.775702
# 	Dev error (no dropout): 0.785279
# 	Ave epoch time: 6.409132
# 	100 epochs will take 0:10:40.913215
# Cost after epoch 10: 0.772615
# 	Dev error (no dropout): 0.782768
# Parameters have been trained!
# Train cost (No dropout): 0.7226457
# Test cost (No dropout): 0.7683161

# %%
model.TestModel(500)
# Out:
# VS Greedy: 62.800%	VS Random: 96.000%
# Standard metric: 148.80
