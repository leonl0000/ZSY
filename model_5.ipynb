# %%
import model_generator as mg
model = mg.Model([300, 200, 40, 1], 'Model5',  r_discount=.9, c_discount=1)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=100, learning_rate=0.001)
# Out:
# num minibatches:3662
# 	Epoch time:26 seconds
# Cost after epoch 0: 0.678477
# 	Dev error (no dropout): 0.649923
# Cost after epoch 1: 0.653416
# 	Dev error (no dropout): 0.645724
# Cost after epoch 2: 0.648825
# 	Dev error (no dropout): 0.650929
# Cost after epoch 3: 0.648461
# 	Dev error (no dropout): 0.643196
# Cost after epoch 4: 0.647115
# 	Dev error (no dropout): 0.643165
# Cost after epoch 5: 0.646022
# 	Dev error (no dropout): 0.642155
# Cost after epoch 6: 0.645705
# 	Dev error (no dropout): 0.641711
# Cost after epoch 7: 0.644843
# 	Dev error (no dropout): 0.640159
# Cost after epoch 8: 0.645346
# 	Dev error (no dropout): 0.656029
# Cost after epoch 9: 0.644976
# 	Dev error (no dropout): 0.645389
# 	Ave epoch time: 25.728793
# 	100 epochs will take 0:42:52.879286
# Cost after epoch 10: 0.645059
# 	Dev error (no dropout): 0.641490
# Cost after epoch 20: 0.645550
# 	Dev error (no dropout): 0.641222
# Cost after epoch 30: 0.647044
# 	Dev error (no dropout): 0.642602
# Cost after epoch 40: 0.646817
# 	Dev error (no dropout): 0.642749
# Cost after epoch 50: 0.649693
# 	Dev error (no dropout): 0.648181
# Cost after epoch 60: 0.649408
# 	Dev error (no dropout): 0.642885
# Cost after epoch 70: 0.649870
# 	Dev error (no dropout): 0.648876
# Cost after epoch 80: 0.649296
# 	Dev error (no dropout): 0.645858
# Cost after epoch 90: 0.648036
# 	Dev error (no dropout): 0.646248
# Parameters have been trained!
# Train cost (No dropout): 0.6401486
# Test cost (No dropout): 0.642543

# %%
model.TestModel()
# Out:
# VS Greedy: 37.120%	VS Random: 74.460%
# Standard metric: 1605.96

# %%
import zsyGame as zsy

# %%
zsy.stdTest(model.paramFileName, 100)
# Out:
# VS Greedy: 29.000%	VS Random: 76.000%
# Standard metric: 1704.00

# %%
from utils.runn import *

# %%
p = pklLoad(model.paramFileName)

# %%
p
# Out:
# {'W1': array([[-0.07358389,  0.04881795, -0.0621511 , ..., -0.06274223,
#          -0.0227316 , -0.12426365],
#         [ 0.40813205,  0.39894935,  0.0962988 , ...,  0.4216434 ,
#           0.25959873,  0.30969614],
#         [-0.14577912,  0.1110725 ,  0.8310526 , ...,  0.7864308 ,
#           0.6147308 ,  0.7322107 ],
#         ...,
#         [-0.07131977, -0.15502663,  0.07203791, ..., -0.03186033,
#          -0.17084788, -0.11685088],
#         [-1.8260037 , -1.931454  , -2.0495965 , ...,  1.0457444 ,
#           1.0116696 ,  0.9567087 ],
#         [-0.59660316, -0.94525003, -1.1969033 , ...,  0.8272302 ,
#           0.7145885 ,  0.6657418 ]], dtype=float32),
#  'W2': array([[ 0.15362544, -2.202729  , -1.3894416 , ...,  0.1121674 ,
#          -0.6262696 , -0.12728783],
#         [-0.1035201 , -1.9612021 , -0.9724662 , ..., -0.00459961,
#          -1.2763565 , -0.5721463 ],
#         [-0.11362628, -1.6973737 , -1.4708503 , ...,  0.11201972,
#          -1.0364957 , -0.16420078],
#         ...,
#         [-0.03111034, -2.4081147 , -0.98742944, ..., -0.0219116 ,
#          -0.5523662 , -0.76725304],
#         [-0.10125626,  0.69339687,  0.8595277 , ...,  0.14082737,
#           0.49224487,  0.38594854],
#         [-0.07058633,  2.7744148 ,  0.53436726, ...,  0.15531237,
#          -0.09081706,  0.34410942]], dtype=float32),
#  'W3': array([[ 0.6056804 ,  0.16790402,  0.2340942 ,  0.6549382 ,  0.46349657,
#           0.64906985,  0.42746237, -1.6422639 ,  0.31287438,  0.6981708 ,
#          -2.0978618 ,  0.61806744,  0.15309465,  0.3202751 ,  0.83455515,
#           0.8206888 , -1.7942173 , -1.5214353 ,  0.5146546 , -1.4774193 ,
#          -1.827275  , -2.026351  , -1.6344447 , -2.1600604 , -2.2463195 ,
#           0.3608926 , -1.5797044 ,  0.8678544 ,  0.40800035, -1.7564148 ,
#           0.02265029,  0.98386574, -2.0988722 , -2.047331  , -1.8017607 ,
#           0.76295626,  0.6053684 ,  0.46857718, -1.3376279 , -1.4576612 ]],
#        dtype=float32),
#  'b1': array([[-0.03693409],
#         [ 0.1509278 ],
#         [ 0.64501035],
#         [ 0.18937561],
#         [-0.7303744 ],
#         [ 0.42511326],
#         [-0.05654185],
#         [-0.0526297 ],
#         [-0.03937372],
#         [-0.7112135 ],
#         [-0.13435982],
#         [ 0.73117185],
#         [-0.72687095],
#         [ 0.41236985],
#         [-0.7820785 ],
#         [-0.04364539],
#         [-0.06082489],
#         [-0.02790491],
#         [ 0.87678546],
#         [-0.68395394],
#         [-0.13324857],
#         [ 0.14158641],
#         [-0.08291423],
#         [ 0.33339804],
#         [-0.05766374],
#         [-0.87136316],
#         [ 0.38681126],
#         [-0.6549502 ],
#         [-0.06180765],
#         [ 0.6749047 ],
#         [ 0.6184487 ],
#         [-0.07795544],
#         [ 0.57527715],
#         [-0.80515397],
#         [-0.10452944],
#         [-0.70513314],
#         [-0.03530488],
#         [-0.01916725],
#         [-0.30952403],
#         [-0.06564429],
#         [-0.04878033],
#         [-0.7804127 ],
#         [-0.0749879 ],
#         [-0.05840639],
#         [ 0.7712469 ],
#         [ 0.63572264],
#         [-0.09248083],
#         [ 0.9232644 ],
#         [ 0.2823037 ],
#         [-0.82304674],
#         [-0.03114065],
#         [-0.04798203],
#         [-0.03970762],
#         [ 0.96066487],
#         [ 0.3659578 ],
#         [-0.8757824 ],
#         [ 0.6748928 ],
#         [-0.01566587],
#         [-0.08639926],
#         [ 0.92802334],
#         [ 0.793939  ],
#         [-0.08633434],
#         [-0.71077436],
#         [ 0.85077584],
#         [-0.8701828 ],
#         [ 0.07811392],
#         [-0.90865016],
#         [-0.01886976],
#         [ 0.70934886],
#         [ 0.27917624],
#         [-0.8873755 ],
#         [-0.09481965],
#         [-0.07104461],
#         [-0.624434  ],
#         [ 0.9118482 ],
#         [-0.04220359],
#         [-0.56999403],
#         [-0.20819013],
#         [-0.02943704],
#         [-0.60438824],
#         [-0.8155428 ],
#         [-0.10017323],
#         [-0.04512479],
#         [ 0.75416666],
#         [-0.8067636 ],
#         [-0.03426745],
#         [-0.12026645],
#         [-0.805144  ],
#         [-0.72051686],
#         [-0.76060903],
#         [-0.25076765],
#         [ 0.12590678],
#         [-0.81897855],
#         [ 0.44779485],
#         [-0.62262255],
#         [-0.74966604],
#         [-0.08974927],
#         [ 0.5142041 ],
#         [ 0.8975818 ],
#         [-0.7362652 ],
#         [-0.0715642 ],
#         [-0.08718329],
#         [ 0.6149035 ],
#         [-0.6445709 ],
#         [ 0.65839136],
#         [ 0.20418654],
#         [-0.5878404 ],
#         [-0.05224091],
#         [-0.01377922],
#         [ 0.30022493],
#         [ 0.8310603 ],
#         [-0.5693414 ],
#         [ 0.19372182],
#         [-0.27373394],
#         [-0.01555639],
#         [-0.07143184],
#         [-0.17112365],
#         [-0.8502868 ],
#         [-0.6298937 ],
#         [-0.6718356 ],
#         [-0.0932817 ],
#         [-0.05689358],
#         [ 0.88902354],
#         [ 0.5746681 ],
#         [-0.7450737 ],
#         [-0.6593076 ],
#         [-0.84226674],
#         [-0.06136293],
#         [-0.06980646],
#         [-0.8287424 ],
#         [-0.7497645 ],
#         [ 0.89127946],
#         [-0.04895478],
#         [-0.04701412],
#         [-0.6784503 ],
#         [-0.04978145],
#         [-0.78712887],
#         [-0.02797932],
#         [ 0.7255116 ],
#         [-0.03819527],
#         [-0.7825991 ],
#         [ 0.8920905 ],
#         [-0.70752746],
#         [ 0.80886614],
#         [-0.09757823],
#         [ 0.69116783],
#         [ 0.7827077 ],
#         [-0.7965376 ],
#         [-0.06947479],
#         [ 0.24175878],
#         [-0.651195  ],
#         [ 0.7991164 ],
#         [-0.17341045],
#         [-0.11716618],
#         [-0.04772048],
#         [-0.0438594 ],
#         [ 0.12362952],
#         [ 0.60894   ],
#         [-0.04881744],
#         [-0.73118776],
#         [ 0.85337025],
#         [ 0.46698225],
#         [-0.707435  ],
#         [-0.7279911 ],
#         [-0.33943862],
#         [-0.23099396],
#         [ 0.11553519],
#         [-0.7442664 ],
#         [ 0.702887  ],
#         [ 0.5849717 ],
#         [ 0.42981303],
#         [-0.66789234],
#         [ 0.8638482 ],
#         [-0.82526535],
#         [-0.6817301 ],
#         [-0.694888  ],
#         [-0.04761054],
#         [-0.04601889],
#         [ 0.3855107 ],
#         [-0.75192046],
#         [-0.6910339 ],
#         [-0.03456847],
#         [-0.06203272],
#         [-0.03954029],
#         [-0.7318439 ],
#         [ 0.4972978 ],
#         [-0.8294212 ],
#         [ 0.09013703],
#         [-0.05889027],
#         [-0.02743836],
#         [ 0.8947317 ],
#         [-0.0547435 ],
#         [-0.7273351 ],
#         [-0.04714638],
#         [-0.26471418],
#         [-0.06197518],
#         [-0.66198844],
#         [-0.07060546],
#         [ 0.8757328 ],
#         [ 0.5267049 ]], dtype=float32),
#  'b2': array([[-0.76668036],
#         [-0.54787636],
#         [-0.10661759],
#         [-0.7446369 ],
#         [-0.07624587],
#         [-0.18809636],
#         [-0.4665959 ],
#         [-1.0108091 ],
#         [-0.13192876],
#         [ 0.09271168],
#         [ 0.7043126 ],
#         [ 0.08494927],
#         [-0.14410028],
#         [-0.19520532],
#         [ 0.31412047],
#         [-0.09410396],
#         [ 0.7064749 ],
#         [-0.09488983],
#         [-0.08962543],
#         [ 0.3660813 ],
#         [ 0.05445737],
#         [ 0.37398288],
#         [-0.51498973],
#         [ 0.44952518],
#         [ 0.4933618 ],
#         [-0.09332327],
#         [-0.88203603],
#         [ 0.04437824],
#         [-0.20056932],
#         [ 0.9050666 ],
#         [-0.22631879],
#         [ 0.25117683],
#         [ 0.58001053],
#         [ 0.5380636 ],
#         [-0.00791033],
#         [-0.6427718 ],
#         [ 0.19873083],
#         [-0.35733473],
#         [-0.8550873 ],
#         [-1.1909218 ]], dtype=float32),
#  'b3': array([[-3.6123202]], dtype=float32)}
