# %%
import model_generator as mg
model = mg.Model([300, 400, 40, 1], 'Model16',  r_discount=.95, c_discount=.90)
mg.saveHP(model)
model.setData()
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
model.TrainModel(num_epochs=10, learning_rate=0.0001)
# Out:
# num minibatches:3662
# 	Epoch time:34 seconds
# Cost after epoch 0: 0.403690
# 	Dev error (no dropout): 0.324158
# Cost after epoch 1: 0.328686
# 	Dev error (no dropout): 0.317952
# Cost after epoch 2: 0.321344
# 	Dev error (no dropout): 0.313974
# Cost after epoch 3: 0.316982
# 	Dev error (no dropout): 0.311868
# Cost after epoch 4: 0.313302
# 	Dev error (no dropout): 0.310000
# Cost after epoch 5: 0.310446
# 	Dev error (no dropout): 0.306540
# Cost after epoch 6: 0.308254
# 	Dev error (no dropout): 0.306531
# Cost after epoch 7: 0.305866
# 	Dev error (no dropout): 0.305042
# Cost after epoch 8: 0.304559
# 	Dev error (no dropout): 0.304373
# Cost after epoch 9: 0.303225
# 	Dev error (no dropout): 0.303599
# Parameters have been trained!
# Train cost (No dropout): 0.29827642
# Test cost (No dropout): 0.30359903

# %%
import zsyGame as zsy
zsy.stdTest(model.paramFileName, 10000)
